# %% [markdown]
# ### Q3, User will input (2 numbers) write a program to swap the numbers

# %%
a = int(input("Enter your number"))o
b = int(input("Enter ypur number"))
temp = a 
a = b
b = temp
print("value of a:",a)
print("value of b:",b)
# Out:
# Enter your number 40
# Enter ypur number 45
# value of a: 45
# value of b: 40
