# %% [markdown]
# ## "Write a Python program to find the sum of digits of a 3 digit number entered by the user."

# %%
num = int(input("Enter thre digit Number"))
a = num %  10
num = num // 10
b = num % 10
num = num  // 10
c = num // 10 
Total = a+b+c
print(f"Total thre digit number{Total}")
# Out:
# Enter thre digit Number 234
# Total thre digit number7

# %%
34//10
# Out:
# 3
