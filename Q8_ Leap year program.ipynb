# %% [markdown]
#  ## Q8_Leap year program

# %%
year = int(input("Enter Your Year"))

if year % 4 == 0:
    print("Leep Year")
else:
    print("Not a Leep Year")
# Out:
# Enter Your Year 2004
# Leep Year
