# %% [markdown]
# ## Q5.Write a program that will reverse a four digit number.Also it checks whether the reverse is true.

# %%
user = int(input("Enter your For digit Number "))
reverse = int(str(user)[::-1])
print("Original Number ", user)
print("Reversed Number ", reverse)

if user == reverse:
    print("True")
else: 
    print("False")
# Out:
# Enter your For digit Number  3452
# Original Number  3452
# Reversed Number  2543
# False
