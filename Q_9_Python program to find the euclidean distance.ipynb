# %% [markdown]
# ## Q_9 Python program to find the euclidean distance

# %%
x_1 = float(input("Enter x1 of x coordinate"))
y_1 = float(input("Enter y1 of y coordinate"))
x_2 = float(input("Enter x2 of x coordinate"))
y_2 = float(input("Enter y2 of coordinate"))

d = ((x_2 - x_1 )**2 + (y_2 - y_1)**2)**0.5
print(d)
# Out:
# Enter x1 of x coordinate 47
# Enter y1 of y coordinate 23
# Enter x2 of x coordinate 35
# Enter y2 of coordinate 10
# 17.69180601295413
